# %%
git clone https://github.com/miguelscarv/pheye.git
cd pheye
pip install -r requirements.txt

# %%
python generate.py --image_path images/dog_flower.jpg --prompt "What is the dog holding in it's mouth?" --device cuda

# %%
# Instruction: What is the dog holding in it's mouth?
# Response: The dog is holding a flower in its mouth.
